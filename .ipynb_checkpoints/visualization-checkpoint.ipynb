# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_train = pd.read_csv('data/train.csv')
col_sensor = ['cycle','s1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10',
             's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %%
plt.bar(data_train['id'],data_train['cycle'])
plt.show()

# %% [markdown]
# ## visualization

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data = data_train['s3']) #from s1 to s21
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.histplot(data = data_train['s21']) #from s1 to s21
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data = data_train[col_sensor],color = 'g') 
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data = data_train['s4'],orient="h",color = 'g') #from s1 to s21
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.hist(x = data_train['s21'],facecolor = 'g') #from s1 to s21
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x = data_train['s3'], y = data_train['ttf'], facecolor = 'g') #from s1 to s21
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x = data_train['s7'], y = data_train['ttf'], facecolor = 'r') #from s1 to s21
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x = data_train['s9'], y = data_train['ttf'], facecolor = 'b') #from s1 to s21
plt.show()

# %%
from yellowbrick.features import Rank1D
X = data_train[col_sensor]
y = data_train['ttf']
visualizer = Rank1D(algorithm='shapiro')
visualizer.fit(X, y) 
visualizer.transform(X) 
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Shapiro Ranking of 22 Features'}>

# %%
from sklearn.model_selection import train_test_split
X = data_train[col_sensor]
y = data_train['ttf']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from yellowbrick.regressor import PredictionError
model = LinearRegression() # Instantiate the linear model and visualizer
visualizer = PredictionError(model=model, identity=False)
visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.poof()
# Out:
# <AxesSubplot:title={'center':'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
sns.heatmap(data_train[col_sensor].corr(), cmap = 'Blues')
# Out:
# <AxesSubplot:>
