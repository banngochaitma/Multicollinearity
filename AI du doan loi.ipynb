# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_train = pd.read_csv('data/train.csv')

# %%
col_names = ['cycle','setting1','setting2','setting3','s1','s2', 's3', 's4','s5', 's6',  's7', 's8', 's9', 
           's10',  's11', 's12', 's13', 's14', 's15',  's16', 's17', 's18', 's19',  's20', 's21','ttf','label_bnc']

# %%
features = ['cycle','setting1','setting2','setting3','s1','s2', 's3', 's4','s5', 's6',  's7', 's8', 's9', 
           's10',  's11', 's12', 's13', 's14', 's15',  's16', 's17', 's18', 's19',  's20', 's21']
data_train[features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cycle     20631 non-null  int64
#  1   setting1  20631 non-null  float64
#  2   setting2  20631 non-null  float64
#  3   setting3  20631 non-null  float64
#  4   s1        20631 non-null  float64
#  5   s2        20631 non-null  float64
#  6   s3        20631 non-null  float64
#  7   s4        20631 non-null  float64
#  8   s5        20631 non-null  float64
#  9   s6        20631 non-null  float64
#  10  s7        20631 non-null  float64
#  11  s8        20631 non-null  float64
#  12  s9        20631 non-null  float64
#  13  s10       20631 non-null  float64
#  14  s11       20631 non-null  float64
#  15  s12       20631 non-null  float64
#  16  s13       20631 non-null  float64
#  17  s14       20631 non-null  float64
#  18  s15       20631 non-null  float64
# ...

# %%
data_train[col_names].isnull().sum()
# Out:
# cycle        0
# setting1     0
# setting2     0
# setting3     0
# s1           0
# s2           0
# s3           0
# s4           0
# s5           0
# s6           0
# s7           0
# s8           0
# s9           0
# s10          0
# s11          0
# s12          0
# s13          0
# s14          0
# s15          0
# s16          0
# s17          0
# s18          0
# s19          0
# s20          0
# s21          0
# ttf          0
# label_bnc    0
# dtype: int64

# %%
data = data_train[features]
data.describe()
# Out:
#               cycle      setting1      setting2  setting3        s1  \
# count  20631.000000  20631.000000  20631.000000   20631.0  20631.00
# mean     108.807862     -0.000009      0.000002     100.0    518.67
# std       68.880990      0.002187      0.000293       0.0      0.00
# min        1.000000     -0.008700     -0.000600     100.0    518.67
# 25%       52.000000     -0.001500     -0.000200     100.0    518.67
# 50%      104.000000      0.000000      0.000000     100.0    518.67
# 75%      156.000000      0.001500      0.000300     100.0    518.67
# max      362.000000      0.008700      0.000600     100.0    518.67
#
#                  s2            s3            s4            s5            s6  \
# count  20631.000000  20631.000000  20631.000000  2.063100e+04  20631.000000
# mean     642.680934   1590.523119   1408.933782  1.462000e+01     21.609803
# std        0.500053      6.131150      9.000605  1.776400e-15      0.001389
# ...

# %% [markdown]
# ## Biểu diễn dữ liệu khuyết thiếu:

# %%
# %matplotlib inline
sns.heatmap(data=data.isnull(), yticklabels=False, cbar =False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## phân loại

# %%
from yellowbrick.target import ClassBalance
visualizer = ClassBalance(labels=['0','1'])
X = data
y= data_train['label_bnc']
visualizer.fit(y)        
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Class Balance for 20,631 Instances'}, ylabel='support'>

# %% [markdown]
# ## giá trị ngoại lai

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data = data['s4'],orient="h",color = 'g') #from s1 to s21
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data = data['s7'],orient="h",color = 'g') #from s1 to s21
plt.show()

# %% [markdown]
# ## xem dạng phân phối

# %%
sns.distplot(a=X['s3'], kde=True)
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='s3', ylabel='Density'>

# %%
sns.distplot(a=X['s4'], kde=True)
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='s4', ylabel='Density'>

# %%
plt.figure(figsize=(10,5))
plt.hist(x = data['s3'],facecolor = 'g') #from s1 to s21
plt.show()

# %% [markdown]
# ## phân tán

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x = data['s3'], y = data_train['ttf'], facecolor = 'g') #from s1 to s21
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x = data['s7'], y = data_train['ttf'], facecolor = 'g') #from s1 to s21
plt.show()

# %% [markdown]
# ## so sánh nhiều features với nhau và mối quan hệ giữa chúng.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data_train[col_names].corr(),cmap= 'Accent')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
def vif_scores(df):
    VIF_Scores = pd.DataFrame()
    VIF_Scores["Independent Features"] = df.columns
    VIF_Scores["VIF Scores"] = [variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
    return VIF_Scores
df1= data_train[col_names].iloc[:,:-2]
vif_scores(df1)
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#    Independent Features    VIF Scores
# 0                 cycle  2.101638e+00
# 1              setting1  1.001915e+00
# 2              setting2  1.001098e+00
# 3              setting3  0.000000e+00
# 4                    s1  0.000000e+00
# 5                    s2  2.640391e+00
# 6                    s3  2.292816e+00
# 7                    s4  4.601251e+00
# 8                    s5  1.380318e-07
# 9                    s6  1.031189e+00
# 10                   s7  4.346102e+00
# 11                   s8  4.714800e+00
# 12                   s9  1.789110e+01
# 13                  s10  0.000000e+00
# 14                  s11  6.034403e+00
# 15                  s12  5.302652e+00
# 16                  s13  4.702970e+00
# 17                  s14  1.727410e+01
# ...

# %% [markdown]
# ## Loại bỏ features

# %%
col_name2 = ['cycle','s2', 's3', 's4',  's7', 's8', 
          's11', 's12', 's13','s14', 's15',  's16', 's17',  's20', 's21']
